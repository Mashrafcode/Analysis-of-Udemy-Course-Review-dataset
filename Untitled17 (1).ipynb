# %% [markdown]
# ## 1.Overview of the data frame

# %%
import pandas as pd
from datetime import datetime
from pytz import utc
import matplotlib.pyplot as plt
data=pd.read_csv("reviews.csv", parse_dates=['Timestamp'])

# %%
data.head()
# Out:
#                                          Course Name           Timestamp  \
# 0  The Python Mega Course: Build 10 Real World Ap... 2021-04-02 06:25:52
# 1  The Python Mega Course: Build 10 Real World Ap... 2021-04-02 05:12:34
# 2  The Python Mega Course: Build 10 Real World Ap... 2021-04-02 05:11:03
# 3  The Python Mega Course: Build 10 Real World Ap... 2021-04-02 03:33:24
# 4  The Python Mega Course: Build 10 Real World Ap... 2021-04-02 03:31:49
#
#    Rating Comment
# 0     4.0     NaN
# 1     4.0     NaN
# 2     4.0     NaN
# 3     5.0     NaN
# 4     4.5     NaN

# %%
data.shape
# Out:
# (45000, 4)

# %%
data.hist('Rating')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000163499A6898>]],
#       dtype=object)

# %% [markdown]
# ## 2.Selecting a data from the dataframe

# %%
data
# Out:
#                                              Course Name           Timestamp  \
# 0      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 06:25:52
# 1      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 05:12:34
# 2      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 05:11:03
# 3      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 03:33:24
# 4      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 03:31:49
# 5      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 01:10:06
# 6      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 00:44:54
# 7      The Python Mega Course: Build 10 Real World Ap... 2021-04-01 23:42:02
# 8      The Python Mega Course: Build 10 Real World Ap... 2021-04-01 21:58:40
# 9      The Python Mega Course: Build 10 Real World Ap... 2021-04-01 20:13:27
# 10     The Complete Python Course: Build 10 Professio... 2021-04-01 18:56:12
# ...

# %% [markdown]
# ### Select a column

# %%
data['Rating']
# Out:
# 0        4.0
# 1        4.0
# 2        4.0
# 3        5.0
# 4        4.5
# 5        4.5
# 6        4.5
# 7        5.0
# 8        5.0
# 9        5.0
# 10       4.0
# 11       5.0
# 12       4.5
# 13       4.0
# 14       4.0
# 15       4.5
# 16       5.0
# 17       3.5
# 18       4.5
# 19       4.5
# 20       4.5
# 21       4.0
# 22       5.0
# 23       5.0
# 24       4.0
# 25       5.0
# 26       4.0
# 27       5.0
# 28       5.0
# 29       4.0
#         ...
# 44970    5.0
# 44971    5.0
# 44972    5.0
# 44973    5.0
# 44974    5.0
# 44975    5.0
# 44976    5.0
# 44977    3.5
# 44978    5.0
# 44979    3.5
# 44980    5.0
# 44981    5.0
# 44982    4.0
# 44983    4.5
# 44984    4.0
# 44985    5.0
# 44986    5.0
# 44987    5.0
# 44988    5.0
# 44989    3.0
# 44990    4.5
# 44991    4.0
# 44992    5.0
# 44993    5.0
# 44994    5.0
# 44995    4.0
# 44996    5.0
# 44997    5.0
# 44998    5.0
# 44999    5.0
# Name: Rating, Length: 45000, dtype: float64

# %% [markdown]
# ## Select a multiple columns

# %%
data[['Course Name', 'Rating']]
# Out:
#                                              Course Name  Rating
# 0      The Python Mega Course: Build 10 Real World Ap...     4.0
# 1      The Python Mega Course: Build 10 Real World Ap...     4.0
# 2      The Python Mega Course: Build 10 Real World Ap...     4.0
# 3      The Python Mega Course: Build 10 Real World Ap...     5.0
# 4      The Python Mega Course: Build 10 Real World Ap...     4.5
# 5      The Python Mega Course: Build 10 Real World Ap...     4.5
# 6      The Python Mega Course: Build 10 Real World Ap...     4.5
# 7      The Python Mega Course: Build 10 Real World Ap...     5.0
# 8      The Python Mega Course: Build 10 Real World Ap...     5.0
# 9      The Python Mega Course: Build 10 Real World Ap...     5.0
# 10     The Complete Python Course: Build 10 Professio...     4.0
# 11     The Python Mega Course: Build 10 Real World Ap...     5.0
# 12     100 Python Exercises I: Evaluate and Improve Y...     4.5
# ...

# %% [markdown]
# ## Selecting a row

# %%
data.iloc[3]
# Out:
# Course Name    The Python Mega Course: Build 10 Real World Ap...
# Timestamp                                    2021-04-02 03:33:24
# Rating                                                         5
# Comment                                                      NaN
# Name: 3, dtype: object

# %% [markdown]
# ### Selecting a multiple row

# %%
data.iloc[1:3]
# Out:
#                                          Course Name           Timestamp  \
# 1  The Python Mega Course: Build 10 Real World Ap... 2021-04-02 05:12:34
# 2  The Python Mega Course: Build 10 Real World Ap... 2021-04-02 05:11:03
#
#    Rating Comment
# 1     4.0     NaN
# 2     4.0     NaN

# %% [markdown]
# ### Selecting a section

# %%
data[['Course Name','Rating']].iloc[1:3]
# Out:
#                                          Course Name  Rating
# 1  The Python Mega Course: Build 10 Real World Ap...     4.0
# 2  The Python Mega Course: Build 10 Real World Ap...     4.0

# %% [markdown]
# ### Selecting a cell

# %%
data['Rating'].iloc[2]
# Out:
# 4.0

# %%
data.at[2, 'Rating']
# Out:
# 4.0

# %% [markdown]
# ## 3. Filtering data based on conditions

# %% [markdown]
# ### One condition

# %%
data[data['Rating']>4]
# Out:
#                                              Course Name           Timestamp  \
# 3      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 03:33:24
# 4      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 03:31:49
# 5      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 01:10:06
# 6      The Python Mega Course: Build 10 Real World Ap... 2021-04-02 00:44:54
# 7      The Python Mega Course: Build 10 Real World Ap... 2021-04-01 23:42:02
# 8      The Python Mega Course: Build 10 Real World Ap... 2021-04-01 21:58:40
# 9      The Python Mega Course: Build 10 Real World Ap... 2021-04-01 20:13:27
# 11     The Python Mega Course: Build 10 Real World Ap... 2021-04-01 15:25:18
# 12     100 Python Exercises I: Evaluate and Improve Y... 2021-04-01 15:03:17
# 15     The Python Mega Course: Build 10 Real World Ap... 2021-04-01 12:16:11
# 16     The Python Mega Course: Build 10 Real World Ap... 2021-04-01 09:38:30
# ...

# %% [markdown]
# ### Multiple Conditions

# %%
data[(data['Rating']>4) & (data['Course Name']=='The Complete Python Course: Build 10 Professional OOP Apps')]
# Out:
#                                             Course Name           Timestamp  \
# 31    The Complete Python Course: Build 10 Professio... 2021-04-01 01:32:52
# 34    The Complete Python Course: Build 10 Professio... 2021-03-31 22:53:04
# 43    The Complete Python Course: Build 10 Professio... 2021-03-31 19:15:25
# 45    The Complete Python Course: Build 10 Professio... 2021-03-31 17:23:15
# 101   The Complete Python Course: Build 10 Professio... 2021-03-29 21:54:00
# 106   The Complete Python Course: Build 10 Professio... 2021-03-29 16:07:43
# 119   The Complete Python Course: Build 10 Professio... 2021-03-29 12:33:06
# 128   The Complete Python Course: Build 10 Professio... 2021-03-28 20:07:56
# 148   The Complete Python Course: Build 10 Professio... 2021-03-28 08:55:52
# 166   The Complete Python Course: Build 10 Professio... 2021-03-27 06:30:34
# 179   The Complete Python Course: Build 10 Professio... 2021-03-26 12:50:16
# ...

# %% [markdown]
# ## 4. Time-based filtering

# %%
data[(data['Timestamp']>=datetime(2020, 7, 1)) & (data['Timestamp']<=datetime(2020, 12, 31))]
# Out:
#                                             Course Name           Timestamp  \
# 3065  Interactive Data Visualization with Python and... 2020-12-30 23:28:34
# 3066  The Python Mega Course: Build 10 Real World Ap... 2020-12-30 22:59:02
# 3067  The Python Mega Course: Build 10 Real World Ap... 2020-12-30 22:40:10
# 3068  The Python Mega Course: Build 10 Real World Ap... 2020-12-30 21:56:41
# 3069  The Python Mega Course: Build 10 Real World Ap... 2020-12-30 21:14:34
# 3070  The Python Mega Course: Build 10 Real World Ap... 2020-12-30 21:09:16
# 3071  The Python Mega Course: Build 10 Real World Ap... 2020-12-30 20:58:29
# 3072  The Python Mega Course: Build 10 Real World Ap... 2020-12-30 20:09:33
# 3073                 Python for Beginners with Examples 2020-12-30 19:30:23
# 3074                        Data Processing with Python 2020-12-30 19:02:30
# 3075  The Python Mega Course: Build 10 Real World Ap... 2020-12-30 18:30:32
# ...

# %% [markdown]
# ## 5. From data to information

# %% [markdown]
# ### Average Rating

# %%
data['Rating'].mean()
# Out:
# 4.442155555555556

# %% [markdown]
# ### Average Rating for a particular course

# %%
data[data['Course Name']=='The Python Mega Course: Build 10 Real World Applications']['Rating'].mean()
# Out:
# 4.477270180942244

# %% [markdown]
# ### Average Rating of a particular period

# %%
data[(data['Timestamp']>=datetime(2020, 1, 1)) & (data['Timestamp']<=datetime(2020, 12, 31))]['Rating'].mean()
# Out:
# 4.476541271662339

# %% [markdown]
# ### Average Rating of a particular period of a particular course

# %%
data[(data['Timestamp']>=datetime(2020, 7, 1)) & (data['Timestamp']<=datetime(2020, 12, 31))
    & (data['Course Name']=='The Python Mega Course: Build 10 Real World Applications')]['Rating'].mean()
# Out:
# 4.520265724857047

# %% [markdown]
# ### Average of uncommented Ratings

# %%
data[data['Comment'].isnull()]['Rating'].mean()
# Out:
# 4.433679746603492

# %% [markdown]
# ### Average of commented Ratings

# %%
data[data['Comment'].notnull()]['Rating'].mean()
# Out:
# 4.489777908515959

# %% [markdown]
# ### Number of uncommented Ratings

# %%
data[data['Comment'].isnull()]['Rating'].count()
# Out:
# 38201

# %% [markdown]
# ### Number of commented Ratings

# %%
data[data['Comment'].notnull()]['Rating'].count()
# Out:
# 6799

# %% [markdown]
# ### Number of comments containing a certain word

# %%
data[data['Comment'].str.contains('accent',na=False)]['Rating'].count()
# Out:
# 77

# %% [markdown]
# ### Average of comments containing a certain word

# %%
data[data['Comment'].str.contains('accent',na=False)]['Rating'].mean()
# Out:
# 3.8636363636363638

# %% [markdown]
# ### Aggreating and Plotting Average Ratings by Day

# %%
data['Day']=data['Timestamp'].dt.date
day_average=data.groupby(['Day']).mean()
plt.figure(figsize=(25,3))
plt.plot(day_average.index, day_average['Rating'])

# %%
day_average['Rating'].min()
# Out:
# 3.7916666666666665

# %% [markdown]
# ### Rating average by week

# %%
data['Week'] = data['Timestamp'].dt.strftime('%m-%U')
week_average=data.groupby(['Week']).mean()
plt.figure(figsize=(25,3))
plt.plot(week_average.index,week_average['Rating'])

# %% [markdown]
# ### Average Rating by Month

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%m')
month_average=data.groupby(['Month']).mean()
plt.figure(figsize=(25,3))
plt.plot(month_average.index,month_average['Rating'])

# %% [markdown]
# ### Average Rating by Month by course

# %%
data['Month'] = data['Timestamp'].dt.strftime('%Y-%m')
month_average_crs = data.groupby(['Month','Course Name'])['Rating'].count().unstack()
month_average_crs.plot(figsize=(25,10))

# %% [markdown]
# ### What day are the people the happiest

# %%
data['Weekday']= data['Timestamp'].dt.strftime('%A')
data['Daynumber']= data['Timestamp'].dt.strftime('%w')
weekday_average= data.groupby(['Weekday','Daynumber']).mean()
weekday_average=weekday_average.sort_values('Daynumber')
plt.figure(figsize=[15,3])
plt.plot(weekday_average.index.get_level_values(0),weekday_average['Rating'])
